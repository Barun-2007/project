# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("car.csv")
df.head
# Out:
# <bound method NDFrame.head of     mileage  sellprice  age
# 0     69000      18000    6
# 1     35000      34000    3
# 2     57000      26100    5
# 3     22500      40000    2
# 4     46000      31500    4
# 5     59000      29400    5
# 6     52000      32000    5
# 7     72000      19300    6
# 8     91000      12000    8
# 9     67000      22000    6
# 10    83000      20000    7
# 11    79000      21000    7
# 12    59000      33000    5>

# %%
# %matplotlib inline
plt.scatter(df['mileage'],df['age'])

# %%
X=df[['mileage','age']]
Y=df['sellprice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#     mileage  age
# 6     52000    5
# 8     91000    8
# 2     57000    5
# 12    59000    5
# 5     59000    5
# 10    83000    7
# 1     35000    3
# 0     69000    6
# 4     46000    4
# 9     67000    6

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([41842.49106079, 22531.68057211, 18423.93325387])

# %%
lr.score(X_test,Y_test)
# Out:
# 0.9224816911971743
